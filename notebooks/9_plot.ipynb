# %% [markdown]
# # Рисование графиков с помощью библиотеки matplotlib

# %% [markdown]
# ### 1. Создание графика

# %%
import matplotlib.pyplot as plt
from numpy import arange, sin, cos

x = arange(0, 6.2, 0.2)

plt.plot(x, sin(x))

# %%
plt.plot(x, sin(x), 'o-')

# %%
plt.plot(x, sin(x), 'o-', x, cos(x), '^-')

# %%
plt.xlabel('x')
plt.grid(True)
plt.plot(x, sin(x), 'o-', label='sin(x)')
plt.plot(x, cos(x), '^-', label='cos(x)')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# ### 2. Создание нескольких графиков

# %%
x = arange(0, 6.2, 0.2)

plt.subplot(2, 1, 1)
plt.plot(x, sin(x), 'o-')
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.grid(True)

plt.subplot(2, 1, 2)
plt.plot(x, cos(x), '^-')
plt.xlabel('x')
plt.ylabel('cos(x)')
plt.grid(True)

plt.show()

# %% [markdown]
# ### 3. Запись графиков в файл

# %%
x = arange(0, 6.2, 0.2)

plt.subplot(2, 1, 1)
plt.plot(x, sin(x), 'o-')
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.grid(True)

plt.subplot(2, 1, 2)
plt.plot(x, cos(x), '^-')
plt.xlabel('x')
plt.ylabel('cos(x)')
plt.grid(True)

plt.savefig('../images/testplot.svg', format='svg')
